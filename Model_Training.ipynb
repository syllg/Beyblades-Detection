# %% [markdown]
# #**Beyblades Detection**
# ---

# %% [markdown]
# ###Install and Import Library

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 874.0/874.0 kB 14.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import gdown
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# ##Connecting to Google Drive for Dataset Access

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ##Training YOLOv8: Custom Object Detection Using the Beyblade Dataset

# %%
# !yolo train model=yolov8n.pt data='/content/gdrive/MyDrive/TestCase_Kecilin/Beyblade/data.yaml' epochs=80 imgsz=640
# Out:
# Ultralytics YOLOv8.2.99 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
